# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\data science\datascience\data.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   brand                                  name  \
# 0             0           0      HP      Victus 15-fb0157AX Gaming Laptop
# 1             1           1      HP                   15s-fq5007TU Laptop
# 2             2           2    Acer                  One 14 Z8-415 Laptop
# 3             3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4           4   Apple       MacBook Air 2020 MGND3HN Laptop
#
#    price  spec_rating                      processor  \
# 0  49900    73.000000      5th Gen AMD Ryzen 5 5600H
# 1  39900    60.000000   12th Gen Intel Core i3 1215U
# 2  26990    69.323529  11th Gen Intel Core i3 1115G4
# 3  59729    66.000000   12th Gen Intel Core i5 1240P
# 4  69990    69.323529                       Apple M1
#
#                               CPU   Ram Ram_type    ROM ROM_type  \
# 0           Hexa Core, 12 Threads   8GB     DDR4  512GB      SSD
# 1  Hexa Core (2P + 4E), 8 Threads   8GB     DDR4  512GB      SSD
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 888           926        1015  Asus
# 889           927        1016  Asus
# 890           928        1017  Asus
# 891           929        1018  Asus
# 892           930        1019  Asus
#
#                                                   name   price  spec_rating  \
# 888          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop   44990    69.323529
# 889                     TUF A15 FA577RM-HQ032WS Laptop  110000    71.000000
# 890  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...  189990    89.000000
# 891  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop  129990    73.000000
# 892  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop  131990    84.000000
#
#                          processor                             CPU   Ram  \
# 888  13th Gen ‎Intel Core i3 1315U  Hexa Core (2P + 4E), 8 Threads   8GB
# 889      6th Gen AMD Ryzen 7 6800H           Octa Core, 16 Threads  16GB
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
pl

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'brand', 'name', 'price', 'spec_rating',
#        'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU',
#        'display_size', 'resolution_width', 'resolution_height', 'OS',
#        'warranty'],
#       dtype='str')

# %%
df['brand']
# Out:
# 0          HP
# 1          HP
# 2        Acer
# 3      Lenovo
# 4       Apple
#         ...
# 888      Asus
# 889      Asus
# 890      Asus
# 891      Asus
# 892      Asus
# Name: brand, Length: 893, dtype: str

# %%
df[df['brand']=="Apple"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  brand  \
# 4               4           4  Apple
# 21             22          22  Apple
# 95             97         100  Apple
# 158           164         185  Apple
# 206           213         241  Apple
# 213           221         250  Apple
# 215           224         253  Apple
# 375           395         436  Apple
# 376           396         437  Apple
# 468           489         555  Apple
# 469           490         556  Apple
# 483           505         572  Apple
# 504           528         599  Apple
# 505           529         600  Apple
# 513           537         611  Apple
# 514           538         612  Apple
#
#                                           name   price  spec_rating  \
# 4              MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# 21                     MacBook Air 2022 Laptop  104990    69.323529
# 95                  MacBook Air 15 2023 Laptop  126990    69.323529
# ...

# %%
df[["brand"]]
# Out:
#       brand
# 0        HP
# 1        HP
# 2      Acer
# 3    Lenovo
# 4     Apple
# ..      ...
# 888    Asus
# 889    Asus
# 890    Asus
# 891    Asus
# 892    Asus
#
# [893 rows x 1 columns]

# %%
df[['brand','name']]
# Out:
#       brand                                               name
# 0        HP                   Victus 15-fb0157AX Gaming Laptop
# 1        HP                                15s-fq5007TU Laptop
# 2      Acer                               One 14 Z8-415 Laptop
# 3    Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4     Apple                    MacBook Air 2020 MGND3HN Laptop
# ..      ...                                                ...
# 888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
# [893 rows x 2 columns]

# %%
df["brand"].unique()
# Out:
# <StringArray>
# [       'HP',      'Acer',    'Lenovo',     'Apple',      'Dell',      'Asus',
#    'Samsung',   'Ultimus', 'Primebook',       'MSI',   'Infinix',     'Wings',
#      'Honor', 'Zebronics',    'Xiaomi',     'iBall',     'Chuwi',    'Realme',
#      'Avita',    'Walker',    'Huawei',     'Tecno',  'Gigabyte',      'Vaio',
#  'Microsoft',   'Fujitsu',        'LG',   'Ninkear',     'Razer',       'AXL']
# Length: 30, dtype: str

# %%
df["brand"].nunique()
# Out:
# 30

# %%
df["brand"].value_counts()
# Out:
# brand
# HP           186
# Lenovo       169
# Asus         157
# Dell         107
# Acer          84
# MSI           65
# Samsung       28
# Apple         16
# Infinix       15
# LG             9
# Xiaomi         8
# Gigabyte       8
# Fujitsu        6
# Ultimus        4
# Zebronics      4
# Wings          3
# Chuwi          3
# Realme         3
# Tecno          3
# Honor          2
# Huawei         2
# Microsoft      2
# AXL            2
# Primebook      1
# iBall          1
# Avita          1
# Walker         1
# Vaio           1
# Ninkear        1
# Razer          1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# Length: 893, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates() # this have no duplicate values 
# so it will the same as it is and don't drop any duplicate 
# values
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name   price  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop   49900    73.000000
# 1                                  15s-fq5007TU Laptop   39900    60.000000
# 2                                 One 14 Z8-415 Laptop   26990    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop   59729    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop   69990    69.323529
# ...

# %%
df.drop_duplicates(inplace=True) # this will delete the duplicate
# values permanently

# %%
df.isnull() # it will show if there is any null value
# or not
# Out:
#      Unnamed: 0.1  Unnamed: 0  brand   name  price  spec_rating  processor  \
# 0           False       False  False  False  False        False      False
# 1           False       False  False  False  False        False      False
# 2           False       False  False  False  False        False      False
# 3           False       False  False  False  False        False      False
# 4           False       False  False  False  False        False      False
# ..            ...         ...    ...    ...    ...          ...        ...
# 888         False       False  False  False  False        False      False
# 889         False       False  False  False  False        False      False
# 890         False       False  False  False  False        False      False
# 891         False       False  False  False  False        False      False
# 892         False       False  False  False  False        False      False
#
#        CPU    Ram  Ram_type    ROM  ROM_type    GPU  display_size  \
# ...

# %%
df.isnull().sum() # the sum of null will be zero because
# no null values
# Out:
# Unnamed: 0.1         0
# Unnamed: 0           0
# brand                0
# name                 0
# price                0
# spec_rating          0
# processor            0
# CPU                  0
# Ram                  0
# Ram_type             0
# ROM                  0
# ROM_type             0
# GPU                  0
# display_size         0
# resolution_width     0
# resolution_height    0
# OS                   0
# warranty             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
# there is 4 float columns and 4 int columns and 10 
# string values we can convert it

# %%
df['OS'].unique()
# Out:
# <StringArray>
# [     'Windows 11 OS',             'Mac OS',      'Android 11 OS',
#              'DOS OS',      'Windows 10 OS',     'Windows 10  OS',
#           'Chrome OS',         'Windows OS',          'Ubuntu OS',
#     'Mac Catalina OS',         'DOS 3.0 OS',     'Windows 11  OS',
#  'Mac High Sierra OS',   'Mac 10.15.3\t OS']
# Length: 14, dtype: str

# %%
# we can any column form int to string , float to string
# str to int, or change into any other by creating dict and
# changing it by turning in.

# %%
df['warranty'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
# warranty_dict = { 
#     1:"first",2:"second",3:"third",4:"forth"
# }

# %%
# df['warranty']=df['warranty'].map(warranty_dict)
# df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
# df.drop('price',axis=1,inplace=True)
# df # in this we cut the column of price

# %%
# df.drop('ROM',axis=1,inplace=True)
# df

# %%
# df.drop(['brand','name'],axis=1,inplace=True)
# df # we use list to remove two columns at one time
# # in the

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
obj_val = df.select_dtypes(include='O')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4844\122132474.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val = df.select_dtypes(include='O')

# %%
obj_val
# Out:
#       brand                                               name  \
# 0        HP                   Victus 15-fb0157AX Gaming Laptop
# 1        HP                                15s-fq5007TU Laptop
# 2      Acer                               One 14 Z8-415 Laptop
# 3    Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4     Apple                    MacBook Air 2020 MGND3HN Laptop
# ..      ...                                                ...
# 888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#                          processor                             CPU   Ram  \
# 0        5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads   8GB
# ...

# %%
num_val=df.select_dtypes(exclude='O')
num_val
# Out:
#      Unnamed: 0.1  Unnamed: 0   price  spec_rating  display_size  \
# 0               0           0   49900    73.000000          15.6
# 1               1           1   39900    60.000000          15.6
# 2               2           2   26990    69.323529          14.0
# 3               3           3   59729    66.000000          14.0
# 4               4           4   69990    69.323529          13.3
# ..            ...         ...     ...          ...           ...
# 888           926        1015   44990    69.323529          15.6
# 889           927        1016  110000    71.000000          15.6
# 890           928        1017  189990    89.000000          14.0
# 891           929        1018  129990    73.000000          15.6
# 892           930        1019  131990    84.000000          15.6
#
#      resolution_width  resolution_height  warranty
# 0              1920.0             1080.0         1
# 1              1920.0             1080.0         1
# ...

# %%
num_val.columns # it contains all the string values
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'price', 'spec_rating', 'display_size',
#        'resolution_width', 'resolution_height', 'warranty'],
#       dtype='str')

# %%
obj_val.columns # it contains value of int and float
# Out:
# Index(['brand', 'name', 'processor', 'CPU', 'Ram', 'Ram_type', 'ROM',
#        'ROM_type', 'GPU', 'OS'],
#       dtype='str')

# %%
complete_Data =pd.concat([obj_val,num_val],axis=1)
complete_Data
# Out:
#       brand                                               name  \
# 0        HP                   Victus 15-fb0157AX Gaming Laptop
# 1        HP                                15s-fq5007TU Laptop
# 2      Acer                               One 14 Z8-415 Laptop
# 3    Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4     Apple                    MacBook Air 2020 MGND3HN Laptop
# ..      ...                                                ...
# 888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#                          processor                             CPU   Ram  \
# 0        5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads   8GB
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
# now we will do filtering take out a single type of laptop
hp_brand = df[df['brand']=='HP']
hp_brand
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                                    name  \
# 0               0           0    HP        Victus 15-fb0157AX Gaming Laptop
# 1               1           1    HP                     15s-fq5007TU Laptop
# 18             19          19    HP        Victus 15-fa0666TX Gaming Laptop
# 23             24          24    HP                     15s-fq2510tu Laptop
# 25             26          26    HP                     15s-eq2132AU Laptop
# ..            ...         ...   ...                                     ...
# 865           903         992    HP        Victus 15-fb0137AX Gaming Laptop
# 867           905         994    HP  ProBook 445 G8 7K2J8PA Business Laptop
# 872           910         999    HP        Victus 15-fb0131AX Gaming Laptop
# 876           914        1003    HP                     15s-fq3071TU Laptop
# 880           918        1007    HP        Victus 15-fb0135AX Gaming Laptop
#
# ...

# %%
hp_price=hp_brand[hp_brand['price']<=100000]
hp_price
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                                    name  \
# 0               0           0    HP        Victus 15-fb0157AX Gaming Laptop
# 1               1           1    HP                     15s-fq5007TU Laptop
# 18             19          19    HP        Victus 15-fa0666TX Gaming Laptop
# 23             24          24    HP                     15s-fq2510tu Laptop
# 25             26          26    HP                     15s-eq2132AU Laptop
# ..            ...         ...   ...                                     ...
# 865           903         992    HP        Victus 15-fb0137AX Gaming Laptop
# 867           905         994    HP  ProBook 445 G8 7K2J8PA Business Laptop
# 872           910         999    HP        Victus 15-fb0131AX Gaming Laptop
# 876           914        1003    HP                     15s-fq3071TU Laptop
# 880           918        1007    HP        Victus 15-fb0135AX Gaming Laptop
#
# ...

# %%
hp_warranty=hp_price[hp_price['warranty']==3]
hp_warranty
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand              name  price  spec_rating  \
# 481           503         570    HP  EliteBook 840 G6  90464    69.323529
#
#                        processor                   CPU  Ram Ram_type    ROM  \
# 481  8th Gen Intel Core i5 8265U  Quad Core, 8 Threads  8GB     DDR4  512GB
#
#     ROM_type                          GPU  display_size  resolution_width  \
# 481      SSD  Integrated UHD Graphics 620          14.0            1920.0
#
#      resolution_height             OS  warranty
# 481             1080.0  Windows 10 OS         3

# %%
# This we take out we found the hp laptop which
# is less than 100000 price and have 3 year warranty

# %%
Acer_brand=df[df['brand']=='Acer']
Acer_brand
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 7               7           7  Acer
# 22             23          23  Acer
# 27             28          29  Acer
# ..            ...         ...   ...
# 875           913        1002  Acer
# 879           917        1006  Acer
# 881           919        1008  Acer
# 886           924        1013  Acer
# 887           925        1014  Acer
#
#                                              name   price  spec_rating  \
# 2                            One 14 Z8-415 Laptop   26990    69.323529
# 5                         Extensa EX214-53 Laptop   39990    62.000000
# 7             Nitro V ANV15-51 2023 Gaming Laptop   76990    63.000000
# 22   Aspire 7 A715-76G UN.QMYSI.002 Gaming Laptop   54990    72.000000
# 27                Extensa 15 EX215-33 2023 Laptop   28990    69.323529
# ..                                            ...     ...          ...
# ...

# %%
acer_ram=Acer_brand[Acer_brand['Ram']=="8GB"]
acer_ram
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 27             28          29  Acer
# 82             84          87  Acer
# 130           134         148  Acer
# 137           141         155  Acer
# 151           157         177  Acer
# 186           192         215  Acer
# 198           204         232  Acer
# 199           205         233  Acer
# 239           252         284  Acer
# 256           272         305  Acer
# 284           301         337  Acer
# 285           302         338  Acer
# 292           311         349  Acer
# 304           323         362  Acer
# 316           335         375  Acer
# 353           372         413  Acer
# 396           416         468  Acer
# 404           424         479  Acer
# 418           438         501  Acer
# 434           454         518  Acer
# 451           472         536  Acer
# 452           473         537  Acer
# 464           485         549  Acer
# ...

# %%
acer_ram1=acer_ram[acer_ram['Ram_type']=="DDR4"]
acer_ram1
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand  \
# 2               2           2  Acer
# 5               5           5  Acer
# 82             84          87  Acer
# 151           157         177  Acer
# 198           204         232  Acer
# 199           205         233  Acer
# 239           252         284  Acer
# 284           301         337  Acer
# 285           302         338  Acer
# 316           335         375  Acer
# 418           438         501  Acer
# 434           454         518  Acer
# 451           472         536  Acer
# 452           473         537  Acer
# 464           485         549  Acer
# 546           570         650  Acer
# 555           579         659  Acer
# 652           684         766  Acer
# 664           696         778  Acer
# 700           734         818  Acer
# 780           818         903  Acer
# 801           839         924  Acer
# 810           848         935  Acer
# 861           899         987  Acer
# 875           913        1002  Acer
# ...

# %%
acer_price=acer_ram1[acer_ram1['price']<=30000]
acer_price
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                               name  price  \
# 2               2           2  Acer               One 14 Z8-415 Laptop  26990
# 198           204         232  Acer               One 14 Z2-493 Laptop  25449
# 239           252         284  Acer  One 11 Z8-284 UN.013SI.033 Laptop  17990
# 316           335         375  Acer   One 14 Z8-415UN.599SI.009 Laptop  25990
# 546           570         650  Acer  One 11 Z8-284 UN.013SI.032 Laptop  18990
# 780           818         903  Acer               One 14 Z2-493 Laptop  29990
# 801           839         924  Acer          Aspire 3 A315-510P Laptop  29980
# 879           917        1006  Acer      One 14 Z2-493 Business Laptop  29990
#
#      spec_rating                      processor                   CPU  Ram  \
# 2      69.323529  11th Gen Intel Core i3 1115G4  Dual Core, 4 Threads  8GB
# 198    69.323529     3rd Gen AMD Ryzen 3  3250U  Dual Core, 4 Threads  8GB
# ...

# %%
acer_space=acer_price[acer_price['ROM']=="128GB"]
acer_space
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                               name  price  \
# 239           252         284  Acer  One 11 Z8-284 UN.013SI.033 Laptop  17990
#
#      spec_rating            processor                   CPU  Ram Ram_type  \
# 239    69.323529  Intel Celeron N4500  Dual Core, 2 Threads  8GB     DDR4
#
#        ROM ROM_type                   GPU  display_size  resolution_width  \
# 239  128GB      SSD  Intel Integrated UHD          11.6            1366.0
#
#      resolution_height             OS  warranty
# 239              768.0  Windows 11 OS         1

# %%
# Above is the final laptop which suits all the conditions we gave.

# %%
df.query("brand=='Asus' and price<=30000 and Ram=='8GB' and ROM=='256GB'")
# if we want to do all in one than we can do it like this.
# Out:
#      Unnamed: 0.1  Unnamed: 0 brand                                 name  \
# 537           561         641  Asus  Vivobook Go 14 E410KA-EK013W Laptop
# 866           904         993  Asus     Eeebook 15 E510MA-EJ011WS Laptop
#
#      price  spec_rating            processor                   CPU  Ram  \
# 537  23990    69.323529        Intel   N4500  Dual Core, 2 Threads  8GB
# 866  25990    69.323529  Intel Celeron N4020  Dual Core, 2 Threads  8GB
#
#     Ram_type    ROM ROM_type                   GPU  display_size  \
# 537     DDR4  256GB      SSD  Intel Integrated UHD          14.0
# 866     DDR4  256GB      SSD  Intel UHD Integrated          15.6
#
#      resolution_width  resolution_height             OS  warranty
# 537            1920.0             1080.0     Windows OS         1
# 866            1920.0             1080.0  Windows 11 OS         1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       893 non-null    int64
#  1   Unnamed: 0         893 non-null    int64
#  2   brand              893 non-null    str
#  3   name               893 non-null    str
#  4   price              893 non-null    int64
#  5   spec_rating        893 non-null    float64
#  6   processor          893 non-null    str
#  7   CPU                893 non-null    str
#  8   Ram                893 non-null    str
#  9   Ram_type           893 non-null    str
#  10  ROM                893 non-null    str
#  11  ROM_type           893 non-null    str
#  12  GPU                893 non-null    str
#  13  display_size       893 non-null    float64
#  14  resolution_width   893 non-null    float64
#  15  resolution_height  893 non-null    float64
#  16  OS                 893 non-null    str
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# Length: 893, dtype: bool

# %%
x=df.drop('price',axis=1)
x
# Out:
#      Unnamed: 0.1  Unnamed: 0   brand  \
# 0               0           0      HP
# 1               1           1      HP
# 2               2           2    Acer
# 3               3           3  Lenovo
# 4               4           4   Apple
# ..            ...         ...     ...
# 888           926        1015    Asus
# 889           927        1016    Asus
# 890           928        1017    Asus
# 891           929        1018    Asus
# 892           930        1019    Asus
#
#                                                   name  spec_rating  \
# 0                     Victus 15-fb0157AX Gaming Laptop    73.000000
# 1                                  15s-fq5007TU Laptop    60.000000
# 2                                 One 14 Z8-415 Laptop    69.323529
# 3                 Yoga Slim 6 14IAP8 82WU0095IN Laptop    66.000000
# 4                      MacBook Air 2020 MGND3HN Laptop    69.323529
# ..                                                 ...          ...
# ...

# %%
y = df[['price']]
y
# Out:
#       price
# 0     49900
# 1     39900
# 2     26990
# 3     59729
# 4     69990
# ..      ...
# 888   44990
# 889  110000
# 890  189990
# 891  129990
# 892  131990
#
# [893 rows x 1 columns]

# %%
# y = mx + c 
# this is called linear regression 
# this is what a straight line equation is
# thisss issss theeeee enddddddddddddd!
