# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data Science\SITP-12-Th-may-\cust_satisfaction.csv")
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103732 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103732 non-null  str
#  1   Customer Type               103732 non-null  str
#  2   Type of Travel              103732 non-null  str
#  3   Class                       103732 non-null  str
#  4   satisfaction                103732 non-null  str
#  5   Age                         103732 non-null  int64
#  6   Flight Distance             103732 non-null  int64
#  7   Inflight entertainment      103732 non-null  int64
#  8   Baggage handling            103732 non-null  int64
#  9   Cleanliness                 103732 non-null  int64
#  10  Departure Delay in Minutes  103732 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 10.3 MB

# %%
plt.plot(df['satisfaction'])
plt.show()

# %%
df.isnull()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction    Age  \
# 0        False          False           False  False         False  False
# 1        False          False           False  False         False  False
# 2        False          False           False  False         False  False
# 3        False          False           False  False         False  False
# 4        False          False           False  False         False  False
# ...        ...            ...             ...    ...           ...    ...
# 103899   False          False           False  False         False  False
# 103900   False          False           False  False         False  False
# 103901   False          False           False  False         False  False
# 103902   False          False           False  False         False  False
# 103903   False          False           False  False         False  False
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
obj_val = df.select_dtypes(include='O')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11408\122132474.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val = df.select_dtypes(include='O')

# %%
obj_val
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# ...

# %%
num_val = df.select_dtypes(exclude='O')
num_val
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# ...

# %%
num_val.columns
# Out:
# Index(['Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
obj_val.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction'], dtype='str')

# %%
complete_Data = pd.concat([obj_val,num_val],axis =1)
complete_Data
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
customer=df[df['Gender']=='Female']
customer
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 7       Female     Loyal Customer  Business travel  Business
# 8       Female     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103893  Female     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103899  Female  disloyal Customer  Business travel       Eco
# 103902  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# ...

# %%
disloyal = customer[customer['Customer Type']=="disloyal Customer"]
disloyal
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 10      Female  disloyal Customer  Business travel       Eco
# 24      Female  disloyal Customer  Business travel       Eco
# 31      Female  disloyal Customer  Business travel       Eco
# 36      Female  disloyal Customer  Business travel  Business
# 41      Female  disloyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103848  Female  disloyal Customer  Business travel       Eco
# 103892  Female  disloyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103899  Female  disloyal Customer  Business travel       Eco
# 103902  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 10      neutral or dissatisfied   24             1182                       2
# ...

# %%
Business = disloyal[disloyal['Class']=='Business']
Business
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 36      Female  disloyal Customer  Business travel  Business
# 41      Female  disloyal Customer  Business travel  Business
# 58      Female  disloyal Customer  Business travel  Business
# 75      Female  disloyal Customer  Business travel  Business
# 79      Female  disloyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103795  Female  disloyal Customer  Business travel  Business
# 103806  Female  disloyal Customer  Business travel  Business
# 103812  Female  disloyal Customer  Business travel  Business
# 103826  Female  disloyal Customer  Business travel  Business
# 103892  Female  disloyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 36      neutral or dissatisfied   34              883                       5
# ...

# %%
sns.histplot(x = 'Customer Type',y='Type of Travel',hue='Gender',data=df)
plt.show()

# %%
sns.countplot(x = 'satisfaction',data=df)
plt.title("Customer Satisfaction ")
plt.show()

# %%
sns.countplot(x = 'Customer Type',hue='Gender',data=df)
plt.title("Relation")
plt.show()

# %%
sns.scatterplot(x='Age',y='Cleanliness',data = df)
plt.title("Relation Data")
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
sns.relplot(x='Flight Distance',y='Baggage handling',col = 'Customer Type',data = df)
plt.title("Relation Data")
plt.show()

# %%
sns.relplot(x = 'Customer Type',y='Age',hue='Gender',data=df)
plt.title("Relation")
plt.show()

# %%
sns.relplot(x = 'Departure Delay in Minutes',y='Arrival Delay in Minutes',hue='Class',data=df)
plt.title("Relation")
plt.show()

# %%
sns.kdeplot(df['Age'])
plt.show()

# %%
plt.scatter(df['Age'],df['Cleanliness'])
plt.show()
