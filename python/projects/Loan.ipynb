# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sat = pd.read_csv(r"C:\Users\HP\Desktop\Data Science\SITP-12-Th-may-\loan_approval.csv")
sat
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
sat.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
sat.duplicated().sum()
# Out:
# np.int64(0)

# %%
sat.isnull()
# Out:
#        name   city  income  credit_score  loan_amount  years_employed  points  \
# 0     False  False   False         False        False           False   False
# 1     False  False   False         False        False           False   False
# 2     False  False   False         False        False           False   False
# 3     False  False   False         False        False           False   False
# 4     False  False   False         False        False           False   False
# ...     ...    ...     ...           ...          ...             ...     ...
# 1995  False  False   False         False        False           False   False
# 1996  False  False   False         False        False           False   False
# 1997  False  False   False         False        False           False   False
# 1998  False  False   False         False        False           False   False
# 1999  False  False   False         False        False           False   False
#
#       loan_approved
# ...

# %%
sat.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   str
#  1   city            2000 non-null   str
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), str(2)
# memory usage: 111.5 KB

# %%
sat.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='str')

# %%
obj_val = sat.select_dtypes(include='O')
obj_val
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17832\3723886857.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val = sat.select_dtypes(include='O')
#                  name              city
# 0        Allison Hill         East Jill
# 1        Brandon Hall     New Jamesside
# 2        Rhonda Smith      Lake Roberto
# 3     Gabrielle Davis  West Melanieview
# 4        Valerie Gray         Mariastad
# ...               ...               ...
# 1995   James Schaefer         Robertton
# 1996        Diana Lin         New Frank
# 1997    Brandon Meyer        East Haley
# ...

# %%
num_val = sat.select_dtypes(exclude='O')
num_val
# Out:
#       income  credit_score  loan_amount  years_employed  points  loan_approved
# 0     113810           389        39698              27    50.0          False
# 1      44592           729        15446              28    55.0          False
# 2      33278           584        11189              13    45.0          False
# 3     127196           344        48823              29    50.0          False
# 4      66048           496        47174               4    25.0          False
# ...      ...           ...          ...             ...     ...            ...
# 1995   92163           770        12251              13    85.0           True
# 1996   38799           635        48259              17    40.0          False
# 1997   41957           763        16752               5    60.0           True
# 1998  139022           360        24031              35    55.0          False
# 1999   41188           482        31397               6    20.0          False
#
# [2000 rows x 6 columns]

# %%
obj_val.columns
# Out:
# Index(['name', 'city'], dtype='str')

# %%
num_val.columns
# Out:
# Index(['income', 'credit_score', 'loan_amount', 'years_employed', 'points',
#        'loan_approved'],
#       dtype='str')

# %%
complete_data = pd.concat([obj_val,num_val],axis = 1)
complete_data
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
sat.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='str')

# %%
plt.plot(sat["loan_amount"])
plt.show()

# %%
sns.lineplot(sat["years_employed"])
plt.show()

# %%
plt.hist(sat["points"])
plt.show()

# %%
sns.histplot(x = "income",data =sat)
plt.show()

# %%
sns.countplot(x="years_employed",data=sat)
plt.title("Years employed distibution")
plt.xticks(rotation=90)
plt.show()

# %%
sns.kdeplot(x = "income",data = sat)
plt.show()

# %%
plt.scatter(sat["credit_score"],sat["income"])
plt.title("credit score v/s income")
plt.xlabel("Credit Score")
plt.ylabel("Income")
plt.show()

# %%
sns.scatterplot(x = "points",y="years_employed",hue="loan_approved",data= sat)
plt.title("Years Employed v/s Points")
plt.show()

# %%
sns.histplot(x = "points",data=sat,kde=True)
plt.show()

# %%
sns.catplot(y = "income",hue="loan_approved",kind = "bar",data=sat)
plt.show()

# %%
sns.relplot(x="income",y = "credit_score",hue = "loan_approved",data= sat)
plt.title("Relation b/w credit_score and income")
plt.show()

# %%
sns.boxplot(x = "loan_approved",y="income",data=sat)
plt.title("Income vs Loan Approval")
plt.show()

# %%
pay = sat["loan_approved"].value_counts()
plt.pie(pay,labels=pay.index,autopct='%1.1f%%',data=sat)
plt.title("percent of possibility")
plt.show()

# %%
ratings = sat.groupby("loan_approved")[[
    "income",
    "credit_score",
    "loan_amount"
]].mean()

ratings.plot(kind="bar")
plt.title("Average Loan Ratings")
plt.ylabel("Average prediction")
plt.xticks(rotation=0)
plt.show()
