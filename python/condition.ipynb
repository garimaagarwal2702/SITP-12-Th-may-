# %%
print("hello my name is garima")
# Out:
# hello my name is garima

# %% [markdown]
# ## Conditional statement
# Conditional statement are used to decision making in a program by giving
# condition, they use different blocks of code based on *condition*.

# %% [markdown]
# <span style = "color:red"> Types of condition statements in python</span>
#
# * if statement
#
# * if- else statement
#
# * if-elif-else statement
#
# * nested if statement

# %%
num = input("enter your number")
print(num)
print(type(num))
# Out:
# 345
# <class 'str'>

# %%
num = int(input("enter your number"))
print(num)
print(type(num))
# Out:
# 4344
# <class 'int'>

# %%
bal = 5000 # you can take input from user and also can initialize it at starting
withdraw = int(input("enter your amount"))
print(withdraw)

if withdraw <= bal:
    print("your account have money")

else :
    print("your account has not sufficient amount")
# Out:
# 2000
# your account have money

# %%
### student fail and pass

# max = 49
# if max <= 33:
#     print("fail")

# else :
#     print("pass")

marks = int(input("enter your marks::"))
input(marks)
if max >= 33:
    print("pass")

else :
    print("fail")
# Out:
# pass

# %%
# traffic system 

signal = input("signal")
if signal == "red" :
    print("wait")
elif signal == "yellow":
    print("ready")
else :
    print("go")
# Out:
# wait

# %%
# voting system
age = int(input("enter your age:"))
if age <= 18 :
    print("Not able to vote")
else :
    print("You can vote :", age)
# Out:
# You can vote : 19

# %%
# blinkit free delivery 

amount = int(input("enter your total amount"))
print(amount)
if amount <= 200: # agar if run hua to else aur elif run nhi hoga 
    print("no free delivery") # 
    print("add more item to get free delivery")
else :
    print("you will get free delivery")
# Out:
# 4000
# you will get free delivery

# %%
# grading system 

grade = int(input("enter your marks :"))
print(grade)
if grade <= 100 and grade >= 90 :
    print("A++")
elif grade <=90 and grade >= 80:
    print("A")
elif grade <= 80 and grade >= 70:
    print("B")
elif grade <= 70 and grade >= 50:
    print("C+")
elif grade <= 50 and grade >= 36:
    print("C")
else :
    print("F")
# Out:
# 50
# C+

# %%
# if cond:
#     if cond:
#         ##code
#     else:
#         #code
# else:
#     ###code

attendance = int(input("enter your attendance precentage"))
marks = int(input("enter your marks"))
print("your attendance is :",attendance)
print("your marks is :",marks)
if attendance >= 75:
    if marks >= 36:
        print("pass")
    else : 
        print("fail in exam")
else :
    print("Low attendance")
# Out:
# your attendance is : 23
# your marks is : 45
# Low attendance

# %%
Password = int(input("enter your pin"))
amount = float(input("enter withdrawal amount"))
Balance = float(600000)
if Password == 1234:
    if Balance >= amount:
        print("your balance is :-",Balance)
        print("withdrawal amount :-",amount)
        print("your transaction is successful")
    else :
        print("your balance is :-",Balance)
        print("withdrawal amount :-",amount)
        print("Not efficient balance")
else :
    print("Password is not correct")
# Out:
# your balance is :- 600000
# withdrawal amount :- 700000.0
# Not efficient balance

# %%
# largest among three numbers
num1 = int(input("enter your first number:"))
num2 = int(input("enter your second number"))
num3 = int(input("enter your third number"))
print("first number:-", num1)
print("second number:-", num2)
print("third number:-", num3)
if num1 > num2 and num1 > num3:
    print("First is largest")
elif num2 > num3 and num2 > num1:
    print("Second is largest")
else : 
    print("Third is largest")
# Out:
# first number:- 23
# second number:- 23
# third number:- 56
# Third is largest

# %%
number = int(input("Enter your number:-"))
print(number)
if number > 0:
    print("this is positive")
elif number < 0:
    print("this is negative")
else :
    print("this is zero")

# %%
num1 = int(input("enter your first number:"))
num2 = int(input("enter your second number"))
num3 = int(input("enter your third number"))
print("first number:-", num1)
print("second number:-", num2)
print("third number:-", num3)
if num1 > num2 and num1 > num3:
    print("First is largest")
elif num2 > num3 and num2 > num1:
    print("Second is largest")
else : 
    print("Third is largest")

# %%
username = input()
print("Enter your username:-", username)
password = int(input())
print("Enter your password:-", password)
if username == "garimaagarwal444":
    if password == 123445678:
        print("Login successful")
    else :
        print("Password is not correct")
else :
    print("Invalid username")
# Out:
# Enter your username garimaagarwal444
# Enter your password 123445678
# Login successful

# %%
username = input("Enter your username:-")
password = int(input("Enter your password:-"))
if username == "garimaagarwal444":
    if password == 123445678:
        print("Your username is:-",username)
        print("your password is:-", password)
        print("Login successful")
    else :
        print("Your username is:-",username)
        print("Password is not correct")
else :
    print("Invalid username")
# Out:
# Your username is:- garimaagarwal444
# your password is:- 123445678
# Login successful
