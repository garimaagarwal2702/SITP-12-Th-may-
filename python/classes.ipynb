# %% [markdown]
# ### Classes in Python
#
# A class is a blueprint for creating objects.
# It defines the properties (variables) and behaviors (methods) that an object will have.
#
# Example:
#
# Class → Car blueprint
# Object → Actual car
#
# **Pillars of OOP in Python**
#
# Object-Oriented Programming (OOP) has 4 main pillars:
# * Encapsulation
# * Inheritance
# * Polymorphism
# * Abstraction
#
# # 1. Encapsulation
#
# Encapsulation means binding data and methods together inside a class and restricting direct access.
#
# Example:-
#
# class Bank:
#     def __init__(self, balance):
#         self.__balance = balance   # private variable
#
#     def deposit(self, amount):
#         self.__balance += amount
#
#     def show_balance(self):
#         print("Balance:", self.__balance)
#
# b1 = Bank(1000)
#
# b1.deposit(500)
# b1.show_balance()
#
# **Output**
# Balance: 1500
#
# Here __balance is private.
#
# # 2. Inheritance
#
# Inheritance means one class can use properties and methods of another class.
#
# Example:-
#
# class Animal:
#     def sound(self):
#         print("Animal makes sound")
#
# class Dog(Animal):
#     def bark(self):
#         print("Dog barks")
#
# d = Dog()
#
# d.sound()
# d.bark()
#
# **Output**
# Animal makes sound
# Dog barks
#
# Dog inherits from Animal.
#
# # 3. Polymorphism
#
# Polymorphism means same method name behaves differently.
#
# Example:-
#
# class Bird:
#     def sound(self):
#         print("Bird chirps")
#
# class Cat:
#     def sound(self):
#         print("Cat meows")
#
# b = Bird()
# c = Cat()
#
# b.sound()
# c.sound()
#
# **Output**
# Bird chirps
# Cat meows
#
# Same function name sound() gives different outputs.
#
# # 4. Abstraction
#
# Abstraction means hiding internal implementation and showing only important details.
#
# Example:-
#
# from abc import ABC, abstractmethod
#
# class Vehicle(ABC):
#
#     @abstractmethod
#     def start(self):
#         pass
#
# class Car(Vehicle):
#
#     def start(self):
#         print("Car starts with key")
#
# c = Car()
# c.start()
#
# **Output**
# Car starts with key
#
# User only knows start() method, not internal logic.

# %% [markdown]
# | Topic                 | Description                                                        |
# | --------------------- | ------------------------------------------------------------------ |
# | **Class**             | A class is a blueprint used to create objects.                     |
# | **Object**            | An object is an instance of a class.                               |
# | **OOP**               | OOP stands for Object-Oriented Programming.                        |
# | **Syntax**            | `class ClassName:`                                                 |
# | **Constructor**       | `__init__()` is a special method used to initialize object values. |
# | **self Keyword**      | `self` refers to the current object of the class.                  |
# | **Method**            | A function inside a class is called a method.                      |
# | **Attribute**         | Variables inside a class are called attributes.                    |
# | **Instance Variable** | Variables created using `self` are instance variables.             |
# | **Object Creation**   | `obj = ClassName()`                                                |
# | **Advantages**        | Code reusability, better structure, easy maintenance.              |

# %% [markdown]
# | PILLAR | DEFINATION | EXAMPLE
# -----------|---------------------------------------|-------------------------|
# |Encapsulation|Wrapping data and methods into one unit. | Class and Object|
# |Inheritance|One class acquires properties of another class. | Parent -- Child |
# |Polymorphism| Same function behaves differently in different situations.| Method overriding|
# |Abstraction| HIding internal details and showing only important features.| Abstract Class|

# %%
class Classname: # class is created by a class name 
    pass

# %%
class Student:
    pass 
# class is keyword and student is the class

# %%
class LastName:
    pass

# from faastapi import FastAPI

# %%
class Student:
    name= "Ritik" ## class variable
    pass

# %%
class Student:
    name = "garima"
st = Student() ##st is object


# Student = class
#st ==object
# name = attribute )class variable)

# %%
class Student:
    name = "garima"
    branch = "CSE"
    roll_number = "23ESGDS018"
st = Student()

# %%
st.branch # this will give line to line output and will only print output of last one
st.name
st.roll_number
# Out:
# '23ESGDS018'

# %%
print(st.branch)
print(st.roll_number)
print(st.name)
# Out:
# CSE
# 23ESGDS018
# garima

# %%
class College: # one class can access multiple objects.
    college_name = "SGI"
    college_address = "Sikar"
    collage_sp = 42
garima = College() # all this ojects also can access this class 
priya = College()
hemant = College()

# %%
garima.college_name # this object is accesing object from class College
# Out:
# 'SGI'

# %%
priya.college_address
# Out:
# 'Sikar'

# %%
hemant.collage_sp
# Out:
# 42

# %%
class College:
    college_name = "SGI"
    def display(a): # display is method and you have to pass argument in it.
        pass

clg =College()

# %%
clg.display() # it will give error if we don't pass argument in the above display 5

# %%
class College:
    college_name = "SGI"
    college_address = "Sikar"
    collegesp = 43 # ek class se method ke ander properties inherit karne ke liye self is used
    def show(self):
        print(self.college_name)
        print(self.college_address)
        print(self.collegesp)

class Student(College):
    student_name = "Garima"
    student_rollnumber = 19
    student_number = 12345678
    student_branch = "CSE"
st = Student()
st.show()
print(st.student_branch)
# Out:
# SGI
# Sikar
# 43
# CSE

# %%
clg.show() # show method used self
# Out:
# SGI
# Sikar
# 43
