# %%
try:
    pass
except:
    pass
else:
    pass
finally:
    pass

# %%
# a = 10
# b = 0 
# print(a/b)
# there is ZeroDivisionError we can handle it by exception handling
# we just have to apply try and except 
try:
    a = 10
    b = 0 
    print(a/b)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a = int(input ('enter ur first no.'))
    b = int(input('enter ur second no.'))
    print(a/b)
except ValueError as e:
    print(e)
# here is value error if we put any wrong data value if int 
# is given and we write string it will this error
# Out:
# 0.717948717948718

# %%
try:
    a = int(input('enter a no.'))
    b = int(input('enter another no.'))
    print(a/b)
except Exception as e:
    print(e)
# Exception keyword is used in except to verify any error 
# and handle all error
# Out:
# 0.7613636363636364

# %%
# a = 10
# b = 6
# print(e)
# here is error of not defined 
try:
    a = 10
    b=6
    print(f)
except NameError as e:
    print(e)
# Out:
# name 'f' is not defined

# %%
# a = (10,20,30)
# print(a[3])
# there is index out of range error
try:
    a =(10,29,40)
    print(a[3])
except IndexError as e:
    print(e)
# Out:
# tuple index out of range

# %%
# name = "priya"
# number = 89
# name + number
# here is typeerror 
try:
    name = "priya"
    number=67
    name + number
except TypeError as e:
    print(e)
# Out:
# can only concatenate str (not "int") to str

# %%
# types of error 
# NameError
# ValueError
# IndexError
# DivisionByZero
# TypeError
# filenotfounderror
# KeyError
# AttributeError
# ImportError
# ModuleNotFoundError

# %%
try:
    file = open('demo.txt')
except FileNotFoundError as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'demo.txt'

# %%
try:
    file = open('demo.txt')
except Exception as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'demo.txt'

# %%
try:
    num = int(input("enter your number"))
except ValueError as e:
    print("invalid input",e)
else:
    print("your input",num)
# else is used to print the num after handling the error
# Out:
# your input 78

# %%
try:
    num = int(input("enter your number"))
except ValueError as e:
    print("invalid input",e)
else:
    print("your input",num)
finally:
    print("i will print always")
# the condition we pass in finally will always run and print.
# even if any condition run or not (except or else)
# Out:
# your input 67
# i will print always

# %%
age = -5
if age<0:
    raise Exception ("age cannot be negative")
# by raise keyword we can create by ourselves
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 age = -5
#       2 if age<0:
# ----> 3     raise Exception ("age cannot be negative")
#       4 # by raise keyword we can create by ourselves
#
# Exception: age cannot be negative

# %%
name = ""
if name == "":
    raise Exception ("name is empty")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 name = ""
#       2 if name == "":
# ----> 3     raise Exception ("name is empty")
#
# Exception: name is empty

# %%
try:
    age = -5
    if age <0:
        raise Exception ("invalid age")
except ValueError as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 try:
#       2     age = -5
#       3     if age <0:
#       4         raise Exception ("invalid age")
# ----> 5 except ValueError as e:
#       6     print(e)
#
# Exception: invalid age

# %%
class InvalidAgeError(Exception):
    pass
age = 15
if age<18:
    raise InvalidAgeError ("you are not eligible")
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# Cell In[24], line 5
#       1 class InvalidAgeError(Exception):
#       2     pass
#       3 age = 15
#       4 if age<18:
# ----> 5     raise InvalidAgeError ("you are not eligible")
#
# InvalidAgeError: you are not eligible

# %%
class InvalidAgeError(Exception):
    pass
try:
    age = 17
    if age<18:
        raise InvalidAgeError ("you are not eligible")
    print("your can vote")
except InvalidAgeError as e:
    print(e)
# Out:
# you are not eligible

# %%
class Insufficient(Exception):
    pass
try:
    bal = 5000
    a = int(input("enter withdrawal money"))
    if a > bal:
        raise Insufficient("balance is not sufficient")
    print("you can take out money")
except Insufficient as e:
    print(e)
# Out:
# you can take out money

# %%
class PasswordLen(Exception):
    pass
try:
    a = input("Enter your password")
    if len(a)==8:
        if a != "12345678":
            raise PasswordLen("Password is incorrect")
        else:
            print("correct password")
    elif len(a) < 8:
        raise PasswordLen("Len of your password is shorter")
    else:
        raise PasswordLen("len of your password is longer")
except PasswordLen as e:
    print(e)
# Out:
# len of your password is longer

# %%
class PhoneNumberLen(Exception):
    pass
try:
    b = input("Enter your phone number")
    if len(b) == 10:
        if not b.isdigit():
            raise PhoneNumberLen("Phone number contains non-numeric characters")
        else:
            print("Valid phone number")
    elif len(b) < 10:
        raise PhoneNumberLen("Phone number is too short")
    else:
        raise PhoneNumberLen("Phone number is too long")
except PhoneNumberLen as e:
    print(e)
# Out:
# Valid phone number

# %%
class EmailCheck(Exception):
    pass
try:
    email = input("Enter your email")
    if "@" not in email:
        raise EmailCheck ("Email has not @",email)
    if "." not in email:  
        raise EmailCheck ("Email has not .",email)
    if not email.isdigit():
        raise EmailCheck ("Email has no numeric value",email)
    if email.isupper():
        raise EmailCheck ("Email has not capital letter",email)
    if email.islower():
        raise EmailCheck ("Email has not lower letter",email)
    print("valid email")
except EmailCheck as e:
    print(e)
# Out:
# ('Email has no numeric value', 'garima.@')
