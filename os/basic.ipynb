# %% [markdown]
# ### Operating System
# In Python, “Operating System” usually refers to the built-in os module, which allows your program to interact with the underlying operating system (Windows, Linux, macOS, etc.).
#
# 🔹 What is the os module?
#
# The os module provides functions to:
# * Work with files and directories
# * Get system information
# * Run system commands
# * Handle environment variables

# %%
import os  # it means importing something

# %%
os.getcwd() # current working directory where you are working.
# Out:
# 'c:\\Users\\HP\\Desktop\\data science\\os'

# %%
path = r'c:\\Users\\HP\\Desktop\\data science\\os'
os.listdir(path)
# listdir is used to list the files in the passed directory ( list directory)
# r is defined as raw string
# Out:
# ['basic.ipynb', 'hello', 'person', 'student']

# %%
path = r"c:\\Users\\HP\\Desktop\\data science\\os"
print(os.listdir(path))
# this is first method to do it by passing in print
# Out:
# ['basic.ipynb', 'hello', 'person', 'student']

# %%
os.listdir(r"c:\\Users\\HP\\Desktop\\data science\\os")
# this is direct method to do it
# Out:
# ['basic.ipynb', 'hello', 'person', 'student']

# %%
os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\data science\\os'

# %%
os.makedirs("student\\data\\reports")

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'hello', 'person', 'student']

# %%
os.rmdir("hello") # it is used to remove any folder

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.ipynb', 'person', 'student']

# %%
os.rename("student","person") # rename is used to rename the folder

# %%
os.listdir(os.getcwd()) # we are checking by listdir that name is changed or not
# Out:
# ['basic.ipynb', 'person']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP\\Desktop\\data science\\os'

# %%
# os.chdir(r"C:\Users\HP\Desktop\data science\os\basic.ipynb") 
# chdir is used to change directory which we are working on

# %%
os.listdir(os.getcwd())
# now it will show another directory because we changed it.
# Out:
# ['basic.ipynb', 'person']

# %%
path = "C:\Program Files\Adobe\Acrobat DC\Acrobat\Legal\de_DE"

path1 = r"C:\Program Files\Adobe"
path2 = r"Acrobat DC\Acrobat\Legal\de_DE"
complete_path = os.path.join(path1,path2)
print(complete_path)
print("final output:-",os.listdir(complete_path))
# join is used to join two paths. 
# r is raw string here
# Out:
# C:\Program Files\Adobe\Acrobat DC\Acrobat\Legal\de_DE
# ['license.html']

# %%
os.path.isfile(r"C:\Users\HP\Desktop\data science\os\basic.ipynb")
# to check file is in folder or not
# Out:
# True

# %%
os.path.isdir("C:\Program Files\Adobe\Acrobat DC\Acrobat\Legal\de_DE")
# to check the directory
# Out:
# True

# %%
os.path.exists(r"C:\Users\HP\Desktop\data science\os\basic.ipynb")
# it is used to check if path exists or not.
# Out:
# True

# %%
os.path.getsize(r"C:\Users\HP\Desktop\data science\os\basic.ipynb")
# it is used to check the size of the file
# Out:
# 12364

# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |
