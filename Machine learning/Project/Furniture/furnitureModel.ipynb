# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data Science\SITP-12-Th-may-\Machine learning\Project\Furniture\clean_furniture_data.csv")
df
# Out:
#       Unnamed: 0                                          furniture  \
# 0              0                 Bed side table with storage shelf
# 1              1                 Bed side table with storage shelf
# 2              2                            Modern Zigzag TV Table
# 3              3                  Bedside table with storage shelf
# 4              4  Wall Mounted TV Unit with Cabinet TV Stand Uni...
# ...          ...                                                ...
# 1995        1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996        1996                          Coffee table + side table
# 1997        1997                                 Ben Togo Baby Bed
# 1998        1998               Cloud memory foam mattress (medical)
# 1999        1999                         Comfy memory foam mattress
#
#                                                    type  \
# 0                                     Home Decor Center
# 1                                           Modern Home
# 2                                           Modern Home
# 3                                           Modern Home
# 4                                           Modern Home
# ...                                                 ...
# 1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996                                      Hub Furniture
# 1997                                            Bean GO
# 1998                                              CIREM
# 1999                                              CIREM
#
#                                                     url  rate  delivery sale  \
# 0     https://www.jumia.com.eg//ar/home-decor-center...   3.3    172.14  72%
# 1     https://www.jumia.com.eg//ar/modern-home-bedsi...   0.0    172.14  54%
# 2     https://www.jumia.com.eg//ar/generic-zigzag-tv...   0.0    172.14  18%
# 3     https://www.jumia.com.eg//ar/modern-home-bedsi...   0.0    172.14  58%
# 4     https://www.jumia.com.eg//ar/modern-home-wall-...   5.0     52.44  54%
# ...                                                 ...   ...       ...  ...
# 1995  https://www.jumia.com.eg//ar/casio-standard-an...   0.0    656.28   0%
# 1996  https://www.jumia.com.eg//ar/hub-furniture-ae-...   0.0    172.14   0%
# 1997  https://www.jumia.com.eg//ar/bean2go-newborn-b...   0.0     52.44   0%
# 1998  https://www.jumia.com.eg//ar/cirem-cloud-memor...   0.0    172.14   9%
# 1999  https://www.jumia.com.eg//ar/cirem-comfy-medic...   0.0    172.14  10%
#
#         price
# 0      2500.0
# 1      1200.0
# 2      1099.0
# 3      1200.0
# 4      1400.0
# ...       ...
# 1995   1632.0
# 1996  11450.0
# 1997    550.0
# 1998   8495.0
# 1999  10775.0
#
# [2000 rows x 8 columns]

# %%
df.drop("url",axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0                                          furniture  \
# 0              0                 Bed side table with storage shelf
# 1              1                 Bed side table with storage shelf
# 2              2                            Modern Zigzag TV Table
# 3              3                  Bedside table with storage shelf
# 4              4  Wall Mounted TV Unit with Cabinet TV Stand Uni...
# ...          ...                                                ...
# 1995        1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996        1996                          Coffee table + side table
# 1997        1997                                 Ben Togo Baby Bed
# 1998        1998               Cloud memory foam mattress (medical)
# 1999        1999                         Comfy memory foam mattress
#
#                                                    type  rate  delivery sale  \
# 0                                     Home Decor Center   3.3    172.14  72%
# 1                                           Modern Home   0.0    172.14  54%
# 2                                           Modern Home   0.0    172.14  18%
# 3                                           Modern Home   0.0    172.14  58%
# 4                                           Modern Home   5.0     52.44  54%
# ...                                                 ...   ...       ...  ...
# 1995  Casio Standard Analogue Ladys Standard Analog ...   0.0    656.28   0%
# 1996                                      Hub Furniture   0.0    172.14   0%
# 1997                                            Bean GO   0.0     52.44   0%
# 1998                                              CIREM   0.0    172.14   9%
# 1999                                              CIREM   0.0    172.14  10%
#
#         price
# 0      2500.0
# 1      1200.0
# 2      1099.0
# 3      1200.0
# 4      1400.0
# ...       ...
# 1995   1632.0
# 1996  11450.0
# 1997    550.0
# 1998   8495.0
# 1999  10775.0
#
# [2000 rows x 7 columns]

# %%
df.drop("Unnamed: 0",axis =1,inplace=True)
df
# Out:
#                                               furniture  \
# 0                    Bed side table with storage shelf
# 1                    Bed side table with storage shelf
# 2                               Modern Zigzag TV Table
# 3                     Bedside table with storage shelf
# 4     Wall Mounted TV Unit with Cabinet TV Stand Uni...
# ...                                                 ...
# 1995  Casio Standard Analogue Ladys Standard Analog ...
# 1996                          Coffee table + side table
# 1997                                 Ben Togo Baby Bed
# 1998               Cloud memory foam mattress (medical)
# 1999                         Comfy memory foam mattress
#
#                                                    type  rate  delivery sale  \
# 0                                     Home Decor Center   3.3    172.14  72%
# 1                                           Modern Home   0.0    172.14  54%
# 2                                           Modern Home   0.0    172.14  18%
# 3                                           Modern Home   0.0    172.14  58%
# 4                                           Modern Home   5.0     52.44  54%
# ...                                                 ...   ...       ...  ...
# 1995  Casio Standard Analogue Ladys Standard Analog ...   0.0    656.28   0%
# 1996                                      Hub Furniture   0.0    172.14   0%
# 1997                                            Bean GO   0.0     52.44   0%
# 1998                                              CIREM   0.0    172.14   9%
# 1999                                              CIREM   0.0    172.14  10%
#
#         price
# 0      2500.0
# 1      1200.0
# 2      1099.0
# 3      1200.0
# 4      1400.0
# ...       ...
# 1995   1632.0
# 1996  11450.0
# 1997    550.0
# 1998   8495.0
# 1999  10775.0
#
# [2000 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997     True
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(304)

# %%
df.drop_duplicates(inplace=True)

# %%
df["type"].unique()
# Out:
# <StringArray>
# [                                                            'Home Decor Center',
#                                                                    'Modern Home',
#                                        'Modern Home Modern Tv Table   Black Oak',
#                           'Modern Home Modern Table            cm   Light Brown',
#                         'Sarcomisr Manager Medical Office Chair   Black   White',
#                                                   'Rattan Folding Table   Biege',
#  'Modern Home                                                                 W',
#                                                                        'General',
#                                                                      'Sarcomisr',
#                                                            'tv covers Protector',
#  ...
#      'pcs Retro Sweet Eye Work Top Beverages Silicone Coasters skidproof  brown',
#                                                                 'Egypt Antiques',
#                                       'camping hammock  person with tree straps',
#                         'Crystal Door Knobs  Pcs    mm   Pcs    mm Clear Drawer',
#                                            'Sedra Tala Waterproof Buff   Yellow',
#                           'Bestway Pavillo Camping Stool Chair Seat Fold N   No',
#                                     'Wall Mounted Folding Desk    x    cm Black',
#                              'PVC Flocking Air Inflatable Travel Pillow Cushion',
#                                 'Sofa Chair Bean Bag Flocking PVC Garden Lounge',
#             'Casio Standard Analogue Ladys Standard Analog Women s LTP V   G  A']
# Length: 592, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['type'] = le.fit_transform(df['type'])

df
# Out:
#                                               furniture  type  rate  delivery  \
# 0                    Bed side table with storage shelf    173   3.3    172.14
# 1                    Bed side table with storage shelf    272   0.0    172.14
# 2                               Modern Zigzag TV Table    272   0.0    172.14
# 3                     Bedside table with storage shelf    272   0.0    172.14
# 4     Wall Mounted TV Unit with Cabinet TV Stand Uni...   272   5.0     52.44
# ...                                                 ...   ...   ...       ...
# 1992     Sofa Chair Bean Bag Flocking PVC Garden Lounge   484   0.0    566.00
# 1995  Casio Standard Analogue Ladys Standard Analog ...    53   0.0    656.28
# 1996                          Coffee table + side table   213   0.0    172.14
# 1998               Cloud memory foam mattress (medical)    45   0.0    172.14
# 1999                         Comfy memory foam mattress    45   0.0    172.14
#
#      sale    price
# 0     72%   2500.0
# 1     54%   1200.0
# 2     18%   1099.0
# 3     58%   1200.0
# 4     54%   1400.0
# ...   ...      ...
# 1992  44%   2498.0
# 1995   0%   1632.0
# 1996   0%  11450.0
# 1998   9%   8495.0
# 1999  10%  10775.0
#
# [1696 rows x 6 columns]

# %%
x = df.drop("price",axis=1)

# %%
y = df[["price"]]

# %%
x
# Out:
#                                               furniture  type  rate  delivery  \
# 0                    Bed side table with storage shelf    173   3.3    172.14
# 1                    Bed side table with storage shelf    272   0.0    172.14
# 2                               Modern Zigzag TV Table    272   0.0    172.14
# 3                     Bedside table with storage shelf    272   0.0    172.14
# 4     Wall Mounted TV Unit with Cabinet TV Stand Uni...   272   5.0     52.44
# ...                                                 ...   ...   ...       ...
# 1992     Sofa Chair Bean Bag Flocking PVC Garden Lounge   484   0.0    566.00
# 1995  Casio Standard Analogue Ladys Standard Analog ...    53   0.0    656.28
# 1996                          Coffee table + side table   213   0.0    172.14
# 1998               Cloud memory foam mattress (medical)    45   0.0    172.14
# 1999                         Comfy memory foam mattress    45   0.0    172.14
#
#      sale
# 0     72%
# 1     54%
# 2     18%
# 3     58%
# 4     54%
# ...   ...
# 1992  44%
# 1995   0%
# 1996   0%
# 1998   9%
# 1999  10%
#
# [1696 rows x 5 columns]

# %%
y
# Out:
#         price
# 0      2500.0
# 1      1200.0
# 2      1099.0
# 3      1200.0
# 4      1400.0
# ...       ...
# 1992   2498.0
# 1995   1632.0
# 1996  11450.0
# 1998   8495.0
# 1999  10775.0
#
# [1696 rows x 1 columns]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y ,random_state=42, test_size =0.2)
x_train.shape, y_train.shape , x_test.shape, y_test.shape
# Out:
# ((1356, 5), (1356, 1), (340, 5), (340, 1))

# %%
fur_pr = LinearRegression()
fur_pr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 fur_pr = LinearRegression()
# ----> 2 fur_pr.fit(x_train, y_train)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:681, in LinearRegression.fit(self, X, y, sample_weight)
#     677 n_jobs_ = self.n_jobs
#     679 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 681 X, y = validate_data(
#     682     self,
#     683     X,
#     684     y,
#     685     accept_sparse=accept_sparse,
#     686     y_numeric=True,
#     687     multi_output=True,
#     688     force_writeable=True,
#     689 )
#     691 has_sw = sample_weight is not None
#     692 if has_sw:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2039, in NDFrame.__array__(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: 'Modern Home Office Desk - 90*40 - White/Black'
